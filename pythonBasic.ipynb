# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
python --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 python --version
#
# NameError: name 'python' is not defined

# %%
import sys
print (sys.version)
# Out:
# 3.13.3 (v3.13.3:6280bb54784, Apr  8 2025, 10:47:54) [Clang 15.0.0 (clang-1500.3.9.4)]

# %%
if 5 > 2:
    print("Five is greater than two!")
# Out:
# Five is greater than two!

# %%
if 5 > 2:
    print("Five is greater than two!")
if 5 > 2:
        print("Five is greater than two!")
# Out:
# Five is greater than two!
# Five is greater than two!

# %%
if 5 > 2:
    print("Five is greater than two!")
        print("Five is greater than two!")
# Out:
#   Cell In[6], line 3
#     print("Five is greater than two!")
#     ^
# IndentationError: unexpected indent

# %%
x = 5
y = "Hello, World!"
print(x)
print(y)
# Out:
# 5
# Hello, World!

# %%
#This is a coment.
print("Hello, World!")
# Out:
# Hello, World!

# %%
print("Python is fun!")
# Out:
# Python is fun!

# %%
#statments are executed one by one, in the same order as they are written:
print("Hello, World!")
print("Have a good day.")
print("Learning Python is fun!")
# Out:
# Hello, World!
# Have a good day.
# Learning Python is fun!

# %%
#semicolons (Optional, Rarely Used)
print("Hello") ; print("How are you?") ; print("Goodbye")
# Out:
# Hello
# How are you?
# Goodbye

# %% [markdown]
# Print Without a New Line
# By default, the print multiple words on the same line, you can use the end parameter:

# %%
print("Hello, World!", end=" ")
print("I will print on the same line.")
# Out:
# Hello, World! I will print on the same line.

# %%
print(3)
print(358)
print(50000)
# Out:
# 3
# 358
# 50000

# %%
print( 3 + 3)
print(2 * 5)
# Out:
# 6
# 10

# %%
print("I am", 35, "years old.")
# Out:
# I am 35 years old.

# %%
#This is a comment
print("Hello, World!") #This is a comment
# Out:
# Hello, World!

# %%
#print("Hello, World!")
print("Cheers, Mate!")
# Out:
# Cheers, Mate!

# %%
"""
This is comment
written in 
more than just one line
"""
print("Hello, World!")
# Out:
# Hello, World!

# %%
x = 5
y = "John"
print(x)
print(y)
# Out:
# 5
# John

# %%
x = 4       # x is of type int
x = "Sally" # x is now of type str
print(x)
# Out:
# Sally

# %%
x = str(3)    # x will be '3'
y = int(3)    # y will be 3
z = float(3)  # z will be 3.0

print(x)
print(y)
print(z)
# Out:
# 3
# 3
# 3.0

# %%
x = 5
y = "John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
x = "John"
#is the same as
x = 'John'

print(x)
# Out:
# John

# %%
#case sensitive
a = 4
A = "Sally"
print(a)
print(A)
# Out:
# 4
# Sally

# %% [markdown]
# Variable names
# a variable can have a short name (like x and y) or more descriptive name (age, carname, total_volume).
# Rules for the Python variables:
# - A variable name must start with a letter or the underscore character
# - A variable name cannot start with a number
# - A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _)
# - Variable names are case-sensitive (age, Age and AGE are three different variables)
# - A variable name cannot be any of the [Python keywords](https://www.w3schools.com/python/python_ref_keywords.asp)

# %%
myvar = "John"
my_var = "John"
_my_var = "John"
myVar = "John"
MYVAR = "John"
myvar2 = "John"

print(myvar)
print(my_var)
print(_my_var)
print(myVar)
print(MYVAR)
print(myvar2)
# Out:
# John
# John
# John
# John
# John
# John

# %%
#illegal variable names:
2myvar = "John"
my-var = "John"
my var = "John"

# %% [markdown]
# Multi Words Variable Names
# Variable names with more than one word can be difficult to read.
# There are several techniques you can use to make them more readable

# %% [markdown]
# CAMEL CASE
# Each word except the first, start with a capital letter:
#
# myVariableName = "John"

# %% [markdown]
# PASCAL CASE
# Each word starts with a capital letter:
#
# MyVarialeName = "John"

# %% [markdown]
# SNAKE CASE
# Each word is separated by an underscore character:
# my_variable_name = "John"

# %% [markdown]
# Python variables - assign. multiple values
#  Many values to vultile variables
#  python allows you to assign values to multiple variables in one line;
# x, y, z = "Orange", "Banana", "Cherry"
# print(x)
# print(y)
# print(z)

# %% [markdown]
# One Value to multiple variables
# you can assign the same value to multiple variables in one line:
#
# x = y = z = "Orange"
# print(x)
# print(y)
# print(z)

# %% [markdown]
# Unpack a collection
# if you have a collection of values, list, tuple,. Python allows you to extract the values into variables. this is called unpacking
# #unpack a list
# fruits = ["apple", "banana", "cherry"]
# x, y, z = fruits
# print(x)
# print(y)
# print(z)

# %% [markdown]
# Output variables
# the print() function is often used to output variables
# x = "Python is awesome"
# print(x)

# %% [markdown]
# # In the print() function, you output multiple variables, separated by a comma:
# x = "Python"
# y = "is"
# z = "awesome"
# print(x, y, z)

# %% [markdown]
# You can also use the + operator to output multiple variables:
# x = "Python"
# y = "is"
# z = "awesome"
# print(x + y + z)

# %% [markdown]
# For the numbers, the + character works as a mathematical operator:

# %%
x = 5
y = 10
print(x + y)
# Out:
# 15

# %% [markdown]
# In the print ()function, whwn you try to combine a string and a number with the + operator, Python will give you an error.

# %%
x = 5
y = "John"
print(x + y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 x = 5
#       2 y = "John"
# ----> 3 print(x + y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# The best way to output variable in the print () function is to separate them with commas, whic even support different datatypes:

# %%
x = 5
y = "John"
print(x , y)
# Out:
# 5 John

# %% [markdown]
# Python - Global Variables
#
# Global Variables
# Variables that are created outside of a function (as in all of the examples in the previous pages) are known as global variables.
#
# Global avriables can be used by everyone, both inside of functions and outside

# %%
#Create a variable outside of a function, and use it inside the function
x = "awesome"   

def myfunc():
    print("Python is " + x)     

myfunc()
# Out:
# Python is awesome

# %% [markdown]
# If you create a variable with the same name inside a function, this variable will be local, and can only be used inside the function. The global variable with the same name will remain as it was, global and with the original value.

# %%
#Create a variable inside a function, with the same name as the global variable

x = "awesome"

def myfunc():
    x = "fantastic"
    print("Python is " + x)

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic
# Python is awesome

# %% [markdown]
# The Global Keyword
# Normally, when you create a variable inside a function, that variables is local, and can only be used inside the function.
#
# To create a global variable inside a function, you can use the global keyword.

# %%
#if you use the global keyword, the variable belongs to the global scope:
def myfunc():
    global x
    x = "fantastic" 

myfunc()    

print("Python is " + x)
# Out:
# Python is fantastic

# %% [markdown]
# Also, use the global keyword if you want to change a global variable inside a function

# %%
#To change the value of a global variable inside a function, refer to the variable by using the global keyword:
x = "awesome"

def myfunc():
    global x
    x = "fantastic"

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic

# %% [markdown]
# Python Data Types
#
# Built-in Data Types
# In programming, data types is an important concept.
# Variables can store data of different types, and different types can do different things.
# Python has the following data types built-in by default, in these categories:
#     Text Type       : str
#     Numeric Types   : int, float, complex
#     Sequence Types  : list, tuple, range
#     Mapping type    : dict
#     Set Types       : set, frozenset
#     Boolean Type    : bool
#     Binary Types    : bytes, bytearray, memoryview
#     None Type       : NoneType
#
# Getting the Dta Type
# You can get the data type of any object by using the type() function:

# %%
#print the data type of the variable x:
x = 5
print(type(x))
# Out:
# <class 'int'>

# %%
x = "Hello, World!"
print(type(x))
# Out:
# <class 'str'>

# %%
x = 20
print(type(x))
# Out:
# <class 'int'>

# %%
x = 20.5
print(type(x))
# Out:
# <class 'float'>

# %%
x = 1j
print(type(x))
# Out:
# <class 'complex'>

# %%
x = ["apple", "banana", "cherry"]
print(type(x))
# Out:
# <class 'list'>

# %%
x = ("apple", "banana", "cherry")
print(type(x))
# Out:
# <class 'tuple'>

# %%
x = range(6)
print(type(x))
# Out:
# <class 'range'>

# %%
x = {"name" : "John", "age" : 36}
print(type(x))
# Out:
# <class 'dict'>

# %%
x = {"apple", "banana", "cherry"}
print(type(x))
# Out:
# <class 'set'>

# %%
x = frozenset({"apple", "banana", "cherry"})
print(type(x))
# Out:
# <class 'frozenset'>

# %%
x = True
print(type(x))
# Out:
# <class 'bool'>

# %%
x = b"Hello"
print(type(x))
# Out:
# <class 'bytes'>

# %%
x = bytearray(5)
print(type(x))
# Out:
# <class 'bytearray'>

# %%
x = memoryview(bytes(5))
print(type(x))
# Out:
# <class 'memoryview'>

# %%
x = None
print(type(x))
# Out:
# <class 'NoneType'>

# %% [markdown]
# Setting the Specific Data Type
# if you want to specify the data type, you can use the following constructor functions:

# %%
x = str("Hello World")
print(type(x))
# Out:
# <class 'str'>

# %%
x = int(20)
print(type(x))
# Out:
# <class 'int'>

# %% [markdown]
# Python numbers
# There are three numeric types in Python:
# int
# float
# complex
#
# variables of numeric types are created when you assign a value to them:

# %%
x = 1
y = 2.8
z = 1j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# Int
#
# Int, or integer, is. awhole number, positive or negatove, without decimals, of unlimited length.

# %%
x = 1
y = 35612361868146843
z = - 3224847837483

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %% [markdown]
# Float
#
# Float, or floating point number is a number, positive or negatove, containing one or more decimals

# %%
x = 1.10
y = 1.0
z = -35.59

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %% [markdown]
# Float can also be scientific numbers with an "e" to indicate the power of 10

# %%
x = 35e3
y = 12E4
z = -87.7e100

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %% [markdown]
# Complex
#
# Complex numbers are written with a "j" as the imaginary part:

# %%
#Complex
x = 3+5j
y = 5j
z = -5j 

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %% [markdown]
# Type Conversion
# you can convert from one type to another with int(), float(), and complex() methods:

# %%
#Convert from one type to another:
x= 1 #int
y= 2.8 #float
z= 1j #complex

#Convert from one type to another:
a = float(x)
b = int(y)
c = complex(x)

print(a)
print(b)
print(c)

print(type(a))
print(type(b))
print(type(c))
# Out:
# 1.0
# 2
# (1+0j)
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %% [markdown]
# You cannot convert complex numbers into another number type

# %% [markdown]
# RANDOM NUMBER
#
# Python does not have a random () function to mkae a random number, but Python has a built-in module called random that can be used to make random numbers:

# %%
import random
print(random.randrange(1, 10))
# Out:
# 5
