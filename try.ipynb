# %% [markdown]
# <a href="https://colab.research.google.com/github/shopy100/machineLearning/blob/main/try.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")

# %%
from scipy import constants

print(constants.pi)
# Out:
# 3.141592653589793
